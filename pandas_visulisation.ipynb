# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.style.use('presentation')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-89-1f4c42d273de> in <module>()
# ----> 1 plt.style.use('presentation')
#
# /Users/mayankaggarwal/anaconda/lib/python2.7/site-packages/matplotlib/style/core.pyc in use(style)
#     111                        "not a valid URL or path. See `style.available` for "
#     112                        "list of available styles.")
# --> 113                 raise IOError(msg % style)
#     114
#     115
#
# IOError: 'presentation' not found in the style library and input is not a valid URL or path. See `style.available` for list of available styles.

# %%
# %matplotlib inline

# %%
df1=pd.read_csv('df1')
df2=pd.read_csv('df2')
df3=pd.read_csv('df3')

# %%
df1.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1288ca250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x128be72d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x128ce9690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x128d79650>]], dtype=object)

# %%
df2=pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1["A"].plot(kind='hist')

# %%
df1.plot.scatter(x='A',y='B')

# %%
df2.plot.bar(stacked=True)

# %%
df1.plot.hexbin(x='A',y='B',gridsize=15)

# %%
df2.plot.density()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
# Unnamed: 0    1000 non-null object
# A             1000 non-null float64
# B             1000 non-null float64
# C             1000 non-null float64
# D             1000 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 39.1+ KB

# %%
df1['A'].plot.kde(ls='--',lw=1)

# %%
df3.iloc[0:20].plot().area()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-128-47d8b6352e22> in <module>()
# ----> 1 df3.iloc[0:20].plot().area()
#
# AttributeError: 'AxesSubplot' object has no attribute 'area'

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231
